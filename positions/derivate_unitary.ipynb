# %%
import sympy as sp

a = [[sp.Symbol(f'a_{j}{i}') for i in range(0,10)] for j in range(0,10)] 
U = sp.Matrix([[a[i][j] for j in range(8)] for i in range(8)])

# %%
for i in range(0,4): 
    U[i,4] = 1/2
for i in range(4,8):
    U[i,4] = 0
out = U.H* U
U
# Out:
# Matrix([
# [a_00, a_01, a_02, a_03, 0.5, a_05, a_06, a_07],
# [a_10, a_11, a_12, a_13, 0.5, a_15, a_16, a_17],
# [a_20, a_21, a_22, a_23, 0.5, a_25, a_26, a_27],
# [a_30, a_31, a_32, a_33, 0.5, a_35, a_36, a_37],
# [a_40, a_41, a_42, a_43,   0, a_45, a_46, a_47],
# [a_50, a_51, a_52, a_53,   0, a_55, a_56, a_57],
# [a_60, a_61, a_62, a_63,   0, a_65, a_66, a_67],
# [a_70, a_71, a_72, a_73,   0, a_75, a_76, a_77]])

# %%
out
# Out:
# Matrix([
# ...
